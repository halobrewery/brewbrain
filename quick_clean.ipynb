# %%
import shutil
import os
import re
import csv
import random
from pybeerxml.parser import Parser
from style_names import create_style_dict

# %%
from yeast_names import build_yeast_dicts, match_recipe_to_yeast_id, build_style_to_common_yeast_dict
yeast_name_to_id, brand_to_ids, id_to_yeast_names = build_yeast_dicts()

# %%
parser = Parser()
valid_file_count = 0

def clean_replace(s, target):
    return s.replace(target, '').replace("  ", " ").strip()

for dirpath, dirnames, files in os.walk('./original_data'):    
    for file_name in files:
        file_path = str(os.path.join(dirpath, file_name))
        try:
            recipes = parser.parse(file_path)
        except:
            print("Erroneous file found, removing: " + file_path)
            os.remove(file_path)
            continue
        
        recipe_valid = False
        for recipe in recipes:
            for y in recipe.yeasts:
                if not isinstance(y.name, str):
                    # Try turning the name into a code (likely a wyeast strain)...
                    yeast_name = str(int(y.name))
                else:
                    yeast_name = y.name.lower()
                    # Some basic clean-up to start...
                    if "conan" in yeast_name: yeast_name = "vermont ale"
                    elif "super high gravity" in yeast_name or "wlp 099" in yeast_name: yeast_name = "super high gravity ale"
                    elif "super yeast" in yeast_name: yeast_name = "san diego super"
                    elif "chico" in yeast_name: yeast_name = "chico ale"
                    elif "orval" in yeast_name: yeast_name = "brettanomyces bruxellensis"
                    elif "duvel" in yeast_name: yeast_name = "belgian golden ale"
                    elif "dupont" in yeast_name: yeast_name = "french saison ale"
                    else:
                        # Clean up any spelling mistakes, ordering
                        yeast_name = yeast_name.replace("kรถlsch","kolsch").replace("kรถlsh","kolsch").replace("kölsh","kolsch")
                        yeast_name = yeast_name.replace("monastery","monastary").replace("monestary","monastary")
                        yeast_name = yeast_name.replace("california v ale", "california ale v")
                        yeast_name = yeast_name.replace("mã©lange","melange").replace("brettâ€™","brett") \
                            .replace("cã´te","cote").replace("munuch","munich").replace("lellemand","lallemand") \
                            .replace("champagene", "champagne").replace("vemont","vermont")

                if yeast_name not in yeast_name_to_id:
                    # First attempt: Try to find a yeast code to match
                    s = re.search(r"(inis\-|wlp|us\-|([kwst]|oyl|bry)\-|[mg]|\d+/)\s?\-?(\d+(/\d+)?)", yeast_name, flags=re.IGNORECASE)
                    if s != None and len(s.group()) > 0:
                        # We have a potential yeast product id...
                        product_id = s.group().replace("--","-").replace(" ","")
                        if product_id not in yeast_name_to_id:
                            pass
                            #print(f"Product id {product_id} not found for {yeast_name}, file: {file_path}")
                        else:
                            continue

                    # Try removing the word "yeast" (and watch out for any double spaces that may ensue)
                    if clean_replace(yeast_name, "yeast") in yeast_name_to_id:
                        continue
                    # Try replacing "yeast" with "ale" or "lager"
                    if yeast_name.replace("yeast", "ale") in yeast_name_to_id or yeast_name.replace("yeast", "lager") in yeast_name_to_id:
                        continue
                    # Try adding "ale" or "blend" or "lager" to the end
                    if yeast_name+" ale" in yeast_name_to_id or yeast_name+" lager" in yeast_name_to_id or yeast_name+" blend" in yeast_name_to_id:
                        continue

                    # Check for a wyeast code (4 digit code)
                    s = re.search(r"(\d{4})(\D+|$)", yeast_name, flags=re.IGNORECASE)
                    if s != None and len(s.group(1)) > 0:
                        product_id = s.group(1)
                        if product_id in yeast_name_to_id:
                            continue

                    # Try to match the brand name first and then try to figure out
                    # which yeast we're dealing with within that brand 
                    for brand_name, ids in brand_to_ids.items():
                        s = re.search(brand_name, yeast_name, flags=re.IGNORECASE)
                        if s != None and len(s.group()) > 0:
                            # Find the best possible match
                            best_match_count = 0
                            best_match_id = -1
                            for id in ids:
                                count = 0
                                potential_yeast_names = id_to_yeast_names[id]
                                for name in potential_yeast_names:
                                    s = re.search(name, yeast_name, flags=re.IGNORECASE)
                                    if s != None: count += 1
                                if count > best_match_count:
                                    best_match_count = count
                                    best_match_id = id
                            if best_match_id == -1:
                                # Just choose the first id...
                                assert len(ids) > 0
                                best_match_id = ids[0]
                                yeast_name = id_to_yeast_names[best_match_id][0]
                            else:
                                pass
                                #print(f"Found a brand-based match for '{yeast_name}', with brand '{brand_name}', and names: {id_to_yeast_names[best_match_id]}")

                            break


                    # Last attempt - try to match any of the ids directly with the yeast name string
                    found = False
                    best_len = 0
                    best_name = ""
                    for dict_name in yeast_name_to_id:
                        name_opts = f"({dict_name}|{clean_replace(dict_name, 'ale')}|{clean_replace(dict_name,'lager')})"
                        s = re.search(name_opts, yeast_name)
                        if s != None and len(s.group()) > 0:
                            group_len = len(s.group())
                            if best_len < group_len:
                                best_len = group_len
                                best_name = dict_name

                    if best_len == 0:
                        if yeast_name == '- -' or yeast_name == 'default - - -' or '?' in yeast_name or yeast_name == "deleteme":
                            print(f"Moving file with empty/unknown (e.g., '- -') yeast: {file_path}")
                            shutil.copy(file_path, f"./data/_not_matched/{file_name}")
                        else:
                            print(f"No matches for '{yeast_name}', file: {file_path}")
                        break
                    else:
                        recipe_valid = True
                        #print(f"Matched '{yeast_name}' with '{best_name}', file: {file_path}")
        if recipe_valid:
            valid_file_count += 1
            
print(f"Valid files found: {valid_file_count}")
# Out:
# Erroneous file found, removing: ./original_data/.DS_Store
# Moving file with empty/unknown (e.g., '- -') yeast: ./original_data/135/508856.xml
# No matches for 'bock lager ', file: ./original_data/135/bt_22894.xml
# Moving file with empty/unknown (e.g., '- -') yeast: ./original_data/135/318856.xml
# Moving file with empty/unknown (e.g., '- -') yeast: ./original_data/135/386892.xml
# No matches for 'bluestone bsy-l006 stuttgart larger yeast', file: ./original_data/135/366233.xml
# No matches for '1/4 gallon yeast', file: ./original_data/135/9541.xml
# Moving file with empty/unknown (e.g., '- -') yeast: ./original_data/135/564316.xml
# KeyboardInterrupt

# %%
style_to_yeast_ids = build_style_to_common_yeast_dict(yeast_name_to_id)

# %%
style_name_to_id = create_style_dict()

# %%
total_files = 0
total_empty_yeast_files = 0
parser = Parser()
for dirpath, dirnames, files in os.walk('./data/_not_matched'):    
    for file_name in files:
        total_files += 1
        file_path = str(os.path.join(dirpath, file_name))
        try:
            recipes = parser.parse(file_path)
        except:
            print("Erroneous file found, removing: " + file_path)
            os.remove(file_path)
            continue

        recipe = recipes[0]
        style = recipe.style
        style_name = style.name.replace(",", "").lower()
        style_name = re.sub(r"\bblonde\b", "blond", style_name)
        style_name = re.sub(r"\bkölsch\b", "kolsch", style_name)
        style_name = re.sub(r"\bmärzen\b", "marzen", style_name)
        style_name = re.sub(r"\bbière\b", "biere", style_name)
        style_name = re.sub(r"\bdüsseldorf\b", "dusseldorf", style_name)
        style_name = re.sub(r"\bnorthern english brown ale\b", "northern english brown", style_name)
        style_name = style_name.strip()
        
        if style_name == "no profile selected": 
            style_name = "n/a"
            # Just move this file now
            new_filepath = os.path.join("./data/_matched", "111", file_name)
            shutil.move(file_path, new_filepath)
            print(f"Moved N/A style file {file_path} to {new_filepath}")
            continue
            
        #print(f"{style.name}, {style.category}")
        if not style_name in style_name_to_id:
            print(f"Could not find style {style_name}, in database - file: {file_path}")
            continue
            
        for yeast in recipe.yeasts:
            yeast_name = yeast.name.lower().strip()
            if yeast_name == '- -' or yeast_name == 'default - - -' or '?' in yeast_name or yeast_name == "deleteme":
                total_empty_yeast_files += 1
                with open(file_path, "r", encoding="utf-8") as f:
                    sub_yeast_ids = style_to_yeast_ids[style_name]
                    if len(sub_yeast_ids) == 0: print(f"No yeast substitutes found for style {style_name}")
                    sub_yeast_id = random.choice(sub_yeast_ids)
                    sub_yeast_name = id_to_yeast_names[sub_yeast_id]
                    #print(f"substitute yeast name,id: {sub_yeast_name}, {sub_yeast_id}")
                    file_str = f.read()
                    file_str = re.sub(r"<NAME>(\- \-|default \- \- \-|\?|deleteme)</NAME>", f"<NAME>{sub_yeast_name}</NAME>", file_str, re.IGNORECASE)
                    style_id = style_name_to_id[style_name]
                    new_filepath = os.path.join("./data/_matched", str(style_id), file_name)
                    
                    with open(new_filepath, "w+", encoding="utf-8") as new_f:
                        new_f.write(file_str)
                        print(f"Wrote updated file {new_filepath}, from original file {file_path}, deleting original...")
                        os.remove(file_path)
                        break
            else:
                # Just move the file
                style_id = style_name_to_id[style_name]
                new_filepath = os.path.join("./data/_matched", str(style_id), file_name)
                shutil.move(file_path, new_filepath)
                print(f"Moved file {file_path} to {new_filepath}")
                break
                
print(f"Found empty yeast values for {total_empty_yeast_files} / {total_files} files.")
# Out:
# Moved file ./data/_not_matched/_finished/3551.xml to ./data/_matched/119/3551.xml
# Moved file ./data/_not_matched/_finished/11772.xml to ./data/_matched/161/11772.xml
# Moved file ./data/_not_matched/_finished/11766.xml to ./data/_matched/119/11766.xml
# Moved file ./data/_not_matched/_finished/26083.xml to ./data/_matched/21/26083.xml
# Moved file ./data/_not_matched/_finished/6189.xml to ./data/_matched/7/6189.xml
# Moved file ./data/_not_matched/_finished/14578.xml to ./data/_matched/30/14578.xml
# Moved file ./data/_not_matched/_finished/8600.xml to ./data/_matched/121/8600.xml
# Moved file ./data/_not_matched/_finished/27774.xml to ./data/_matched/7/27774.xml
# Moved file ./data/_not_matched/_finished/11761.xml to ./data/_matched/10/11761.xml
# Moved file ./data/_not_matched/_finished/11470.xml to ./data/_matched/104/11470.xml
# Moved file ./data/_not_matched/_finished/4111.xml to ./data/_matched/31/4111.xml
# Moved file ./data/_not_matched/_finished/18479.xml to ./data/_matched/132/18479.xml
# Moved file ./data/_not_matched/_finished/4490.xml to ./data/_matched/7/4490.xml
# Moved file ./data/_not_matched/_finished/18111.xml to ./data/_matched/10/18111.xml
# Moved file ./data/_not_matched/_finished/23179.xml to ./data/_matched/145/23179.xml
# Moved file ./data/_not_matched/_finished/21829.xml to ./data/_matched/7/21829.xml
# Moved file ./data/_not_matched/_finished/1328.xml to ./data/_matched/46/1328.xml
# Moved file ./data/_not_matched/_finished/24410.xml to ./data/_matched/105/24410.xml
# Moved file ./data/_not_matched/_finished/4654.xml to ./data/_matched/102/4654.xml
# Moved file ./data/_not_matched/_finished/4668.xml to ./data/_matched/109/4668.xml
# Moved file ./data/_not_matched/_finished/4669.xml to ./data/_matched/7/4669.xml
# Moved file ./data/_not_matched/_finished/11469.xml to ./data/_matched/57/11469.xml
# Moved file ./data/_not_matched/_finished/2620.xml to ./data/_matched/104/2620.xml
# Moved file ./data/_not_matched/_finished/3954.xml to ./data/_matched/10/3954.xml
# Moved file ./data/_not_matched/_finished/10664.xml to ./data/_matched/104/10664.xml
# Moved file ./data/_not_matched/_finished/9316.xml to ./data/_matched/58/9316.xml
# Moved file ./data/_not_matched/_finished/6959.xml to ./data/_matched/102/6959.xml
# Moved file ./data/_not_matched/_finished/4814.xml to ./data/_matched/119/4814.xml
# Moved file ./data/_not_matched/_finished/20765.xml to ./data/_matched/10/20765.xml
# Moved file ./data/_not_matched/_finished/2452.xml to ./data/_matched/57/2452.xml
# Moved file ./data/_not_matched/_finished/12878.xml to ./data/_matched/134/12878.xml
# Moved file ./data/_not_matched/_finished/6020.xml to ./data/_matched/119/6020.xml
# Moved file ./data/_not_matched/_finished/15889.xml to ./data/_matched/7/15889.xml
# Found empty yeast values for 0 / 33 files.
