# %%
import shutil
import os
import re
from pybeerxml.parser import Parser

# %%
from yeast_db import build_yeast_dicts
yeast_name_to_id, brand_to_ids, id_to_yeast_names = build_yeast_dicts()

# %%
parser = Parser()
valid_file_count = 0

def clean_replace(s, target):
    return s.replace(target, '').replace("  ", " ").strip()

for dirpath, dirnames, files in os.walk('./original_data'):    
    for file_name in files:
        file_path = str(os.path.join(dirpath, file_name))
        try:
            recipes = parser.parse(file_path)
        except:
            print("Erroneous file found, removing: " + file_path)
            os.remove(file_path)
            continue
        
        recipe_valid = False
        for recipe in recipes:
            for y in recipe.yeasts:
                if not isinstance(y.name, str):
                    # Try turning the name into a code (likely a wyeast strain)...
                    yeast_name = str(int(y.name))
                else:
                    yeast_name = y.name.lower()
                    # Some basic clean-up to start...
                    if "conan" in yeast_name: yeast_name = "vermont ale"
                    elif "super high gravity" in yeast_name or "wlp 099" in yeast_name: yeast_name = "super high gravity ale"
                    elif "super yeast" in yeast_name: yeast_name = "san diego super"
                    elif "chico" in yeast_name: yeast_name = "chico ale"
                    elif "orval" in yeast_name: yeast_name = "brettanomyces bruxellensis"
                    elif "duvel" in yeast_name: yeast_name = "belgian golden ale"
                    elif "dupont" in yeast_name: yeast_name = "french saison ale"
                    else:
                        # Clean up any spelling mistakes, ordering
                        yeast_name = yeast_name.replace("kรถlsch","kolsch").replace("kรถlsh","kolsch").replace("kölsh","kolsch")
                        yeast_name = yeast_name.replace("monastery","monastary").replace("monestary","monastary")
                        yeast_name = yeast_name.replace("california v ale", "california ale v")
                        yeast_name = yeast_name.replace("mã©lange","melange").replace("brettâ€™","brett") \
                            .replace("cã´te","cote").replace("munuch","munich").replace("lellemand","lallemand") \
                            .replace("champagene", "champagne").replace("vemont","vermont")

                if yeast_name not in yeast_name_to_id:
                    # First attempt: Try to find a yeast code to match
                    s = re.search(r"(inis\-|wlp|us\-|([kwst]|oyl|bry)\-|[mg]|\d+/)\s?\-?(\d+(/\d+)?)", yeast_name, flags=re.IGNORECASE)
                    if s != None and len(s.group()) > 0:
                        # We have a potential yeast product id...
                        product_id = s.group().replace("--","-").replace(" ","")
                        if product_id not in yeast_name_to_id:
                            pass
                            #print(f"Product id {product_id} not found for {yeast_name}, file: {file_path}")
                        else:
                            continue

                    # Try removing the word "yeast" (and watch out for any double spaces that may ensue)
                    if clean_replace(yeast_name, "yeast") in yeast_name_to_id:
                        continue
                    # Try replacing "yeast" with "ale" or "lager"
                    if yeast_name.replace("yeast", "ale") in yeast_name_to_id or yeast_name.replace("yeast", "lager") in yeast_name_to_id:
                        continue
                    # Try adding "ale" or "blend" or "lager" to the end
                    if yeast_name+" ale" in yeast_name_to_id or yeast_name+" lager" in yeast_name_to_id or yeast_name+" blend" in yeast_name_to_id:
                        continue

                    # Check for a wyeast code (4 digit code)
                    s = re.search(r"(\d{4})(\D+|$)", yeast_name, flags=re.IGNORECASE)
                    if s != None and len(s.group(1)) > 0:
                        product_id = s.group(1)
                        if product_id in yeast_name_to_id:
                            continue

                    # Try to match the brand name first and then try to figure out
                    # which yeast we're dealing with within that brand 
                    for brand_name, ids in brand_to_ids.items():
                        s = re.search(brand_name, yeast_name, flags=re.IGNORECASE)
                        if s != None and len(s.group()) > 0:
                            # Find the best possible match
                            best_match_count = 0
                            best_match_id = -1
                            for id in ids:
                                count = 0
                                potential_yeast_names = id_to_yeast_names[id]
                                for name in potential_yeast_names:
                                    s = re.search(name, yeast_name, flags=re.IGNORECASE)
                                    if s != None: count += 1
                                if count > best_match_count:
                                    best_match_count = count
                                    best_match_id = id
                            if best_match_id == -1:
                                # Just choose the first id...
                                assert len(ids) > 0
                                best_match_id = ids[0]
                                yeast_name = id_to_yeast_names[best_match_id][0]
                            else:
                                pass
                                #print(f"Found a brand-based match for '{yeast_name}', with brand '{brand_name}', and names: {id_to_yeast_names[best_match_id]}")

                            break


                    # Last attempt - try to match any of the ids directly with the yeast name string
                    found = False
                    best_len = 0
                    best_name = ""
                    for dict_name in yeast_name_to_id:
                        name_opts = f"({dict_name}|{clean_replace(dict_name, 'ale')}|{clean_replace(dict_name,'lager')})"
                        s = re.search(name_opts, yeast_name)
                        if s != None and len(s.group()) > 0:
                            group_len = len(s.group())
                            if best_len < group_len:
                                best_len = group_len
                                best_name = dict_name

                    if best_len == 0:
                        if yeast_name == '- -' or yeast_name == 'default - - -' or '?' in yeast_name or yeast_name == "deleteme":
                            print(f"Moving file with empty/unknown (e.g., '- -') yeast: {file_path}")
                            shutil.copy(file_path, f"./data/_not_matched/{file_name}")
                        else:
                            print(f"No matches for '{yeast_name}', file: {file_path}")
                        break
                    else:
                        recipe_valid = True
                        #print(f"Matched '{yeast_name}' with '{best_name}', file: {file_path}")
        if recipe_valid:
            valid_file_count += 1
            
print(f"Valid files found: {valid_file_count}")
# Out:
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/135/508856.xml
# No matches for 'bock lager ', file: ./original_data/135/bt_22894.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/135/318856.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/135/386892.xml
# No matches for 'bluestone bsy-l006 stuttgart larger yeast', file: ./original_data/135/366233.xml
# No matches for '1/4 gallon yeast', file: ./original_data/135/9541.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/135/564316.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/135/567069.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/135/547811.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/135/334482.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/135/559190.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/135/291763.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/135/364689.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/61/450395.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/61/446976.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/61/375227.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/61/371537.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/61/304627.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/95/619217.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/238139.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/216415.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/306174.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/394172.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/337380.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/288770.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/257516.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/523782.xml
# No matches for 'mangrove's', file: ./original_data/132/bt_156369.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/585794.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/374443.xml
# No matches for 'same', file: ./original_data/132/286028.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/188718.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/191089.xml
# No matches for '1l ekstra slurry ', file: ./original_data/132/556325.xml
# No matches for 'same', file: ./original_data/132/106240.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/256197.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/459029.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/576960.xml
# No matches for 'same, 2 packs', file: ./original_data/132/451176.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/279847.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/191562.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/230670.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/619773.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/448750.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/284883.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/bt_173942.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/519655.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/487651.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/575148.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/189688.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/354647.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/275070.xml
# No matches for 'headwarters ale', file: ./original_data/132/bt_183244.xml
# No matches for 'base camp ale', file: ./original_data/132/bt_177110.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/434713.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/470637.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/288648.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/280566.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/226772.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/262441.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/599045.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/289353.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/18479.xml
# No matches for 'headwaters ale (1000)', file: ./original_data/132/bt_105807.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/445305.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/bt_125491.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/242382.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/220513.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/459523.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/231188.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/520221.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/304696.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132/300382.xml
# No matches for 'mangrove's', file: ./original_data/132/bt_167903.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/132
xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/176/283322.xml
# No matches for '1688 strong', file: ./original_data/176/bt_95765.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/555011.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/449174.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/500952.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/290672.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/325219.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/246635.xml
# No matches for 'fm klasztorna medytacja', file: ./original_data/22/bt_145475.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/321055.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/456779.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/279846.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/231427.xml
# No matches for 'ommegang', file: ./original_data/22/bt_57075.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/230504.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/346445.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/291696.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/548794.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/524471.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/590275.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/209633.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/385145.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/433286.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/294673.xml
# No matches for 'dregs, bottle', file: ./original_data/22/bt_138205.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/354738.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/312803.xml
# No matches for 'fm25 klasztorna medytacja', file: ./original_data/22/bt_90522.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/363592.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/377861.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/595881.xml
# No matches for 'norsk farmhaouse', file: ./original_data/22/bt_7145.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/605792.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/342028.xml
# No matches for 'westmalle', file: ./original_data/22/bt_104736.xml
# No matches for 'westmalle', file: ./original_data/22/bt_52464.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/266821.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/231428.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/387202.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/294966.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/223114.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/263321.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/206037.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/395105.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/416533.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/206218.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/208551.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/22/545805.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/149/309651.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/149/477288.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/149/394893.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/149/587490.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/149/506983.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/149/321432.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/149/567540.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/149/428592.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/171/287120.xml
# No matches for 'wheat yeast', file: ./original_data/171/bt_216487.xml
# No matches for 'same', file: ./original_data/171/90295.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/171/396826.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/171/310826.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/171/205423.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/171/471844.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/171/511347.xml
# No matches for 'wheat yeast', file: ./original_data/171/bt_215732.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/171/538297.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/171/222911.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/171/603378.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/171/281564.xml
# No matches for 'feral', file: ./original_data/25/bt_230282.xml
# No matches for 'dregs, bottle', file: ./original_data/25/bt_221993.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/251200.xml
# No matches for 'westmalle', file: ./original_data/25/bt_247421.xml
# No matches for 'dregs, bottle', file: ./original_data/25/bt_15419.xml
# No matches for 'westmalle', file: ./original_data/25/bt_79138.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/254452.xml
# No matches for 'bottle dredges boon oude geuze', file: ./original_data/25/bt_172527.xml
# No matches for 'mount adams blend', file: ./original_data/25/bt_184310.xml
# No matches for 'backyard pear yeast', file: ./original_data/25/bt_48627.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/254928.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/522818.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/258911.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/294841.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/258912.xml
# No matches for 'leuven ale', file: ./original_data/25/bt_59301.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/286245.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/283710.xml
# No matches for '1/2 pack s-05', file: ./original_data/25/40382.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/271540.xml
# No matches for 'westmalle', file: ./original_data/25/bt_58598.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/273157.xml
# No matches for 'crooked stave cmy 001', file: ./original_data/25/bt_111714.xml
# No matches for 'beersel', file: ./original_data/25/bt_110345.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/296119.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/285465.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/366661.xml
# No matches for 'dregs, bottle', file: ./original_data/25/bt_174260.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/364895.xml
# No matches for 'rochefort bottle', file: ./original_data/25/bt_148365.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/252489.xml
# No matches for 'westmalle', file: ./original_data/25/bt_235097.xml
# No matches for 'bbyxxx sourdough', file: ./original_data/25/bt_23188.xml
# Deleting file with empty/unknown (e.g., '- -') yeast: ./original_data/25/366667.xml
# No matches for 'sourdough yeast (b. feb 2013)', file: ./original_data/25/bt_196552.xml
# No matches for 'leuven ale', file: ./original_data/25/bt_103978.xml
# Valid files found: 18375
